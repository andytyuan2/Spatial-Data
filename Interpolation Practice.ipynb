# %% [markdown]
# #
#
# ## Areal interpolation

# %%
import geopandas as gpd
import tobler
import pyinterpolate
import numpy as np
import matplotlib.pyplot as plt

from libpysal import graph
from sklearn import neighbors
from scipy import interpolate

# %%
bas = gpd.read_file("data/Building_as_Symbol.geojson")

bas.head(2)

# %%
bas[["", "geometry"]].explore("", tiles = "CartoDB Positron")
