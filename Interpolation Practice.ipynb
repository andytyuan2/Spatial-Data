# %%
import geopandas as gpd
import tobler
import pyinterpolate
import numpy as np
import matplotlib.pyplot as plt

from libpysal import graph
from sklearn import neighbors
from scipy import interpolate

# %%
bas = gpd.read_file("data/Trapline_area.geojson")

bas.head(2)
# Out:
#        OGF_ID TRAPLINE_AREA_NUMBER   LOCATION_ACCURACY    LOCATION_DESCR  \
# 0  1300846100                SL226  Within 1000 metres  MINOMINATIK LAKE
# 1  1300846123                SL227  Within 1000 metres  WETT LAUFER LAKE
#
#   VERIFICATION_STATUS_FLG  VERIFICATION_STATUS_DATE BUSINESS_EFF_DATE_FLG  \
# 0              Unverified 1998-12-08 00:00:00+00:00             Estimated
# 1              Unverified 1998-12-08 00:00:00+00:00             Estimated
#
#     BUSINESS_EFFECTIVE_DATE  SYSTEM_CALCULATED_AREA  SYSTEM_CALCULATED_LENGTH  \
# 0 2001-03-15 00:00:00+00:00            1.866559e+08                 72899.818
# 1 2001-03-20 00:00:00+00:00            5.596500e+08                105419.513
#
#    GEOMETRY_UPDATE_DATETIME        EFFECTIVE_DATETIME  OBJECTID  \
# 0 2013-05-29 11:34:59+00:00 2013-05-29 09:07:50+00:00      5121
# 1 2013-05-29 11:35:00+00:00 2013-05-29 09:07:49+00:00      5137
#
#                                             geometry
# 0  POLYGON ((-90.64507 51.49139, -90.65135 51.495...
# 1  POLYGON ((-90.82116 51.69826, -90.8321 51.7008...

# %%
bas[["SYSTEM_CALCULATED_AREA", "geometry"]].explore("SYSTEM_CALCULATED_AREA", tiles = "CartoDB Positron")
